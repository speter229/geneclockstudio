# %%
def all_lists_equal(lst):
    return all(sublist == lst[0] for sublist in lst)

def create_dataframe(data, col_names, row_names):
    df = pd.DataFrame({col_names[i]: data[i] for i in range(len(col_names))}, index=row_names)
    return df

# %%
import pandas as pd
#run time 5min

file_path = 'GSE37754_family.soft'

sample_geo = []
sample_cgs=[]
sample_betas=[]
is_beta=False

with open(file_path, 'r') as file:
    for line in file:
        # Check for sample ID line
        if(is_beta==False):
            if line.startswith('^SAMPLE = '):
                current_geo = line.strip().split('= ')[-1]
                sample_geo.append(current_geo)
        
            elif line.startswith('ID_REF	VALUE'):
                actual_betas=[]
                actual_cgs=[]
                is_beta=True
        else:
            if line.startswith('!sample_table_end'):
                sample_cgs.append(actual_cgs)
                sample_betas.append(actual_betas)
                is_beta=False
            else:
                elements=line.strip().split('\t')
                actual_cgs.append(elements[0]) 
                actual_betas.append(elements[1])

# %%
#print(all_lists_equal(sample_cgs)) #so now we can create dataframe since the order and sites are the same
GSE37754_df = create_dataframe(sample_betas, sample_geo, sample_cgs[0])
#THESE BETA VALUES ARENT NORMALIZED YET, THEY MUST BE CONVERTED FROM M-VALUES TO BETA VALUES
GSE37754_df.to_csv('GSE37754_betas_NOT NORMALIZED.csv')

# %%
import pandas as pd
#run time 5min

file_path = 'GSE49149_family.soft'

sample_geo = []
sample_cgs=[]
sample_betas=[]
is_beta=False

with open(file_path, 'r') as file:
    for line in file:
        # Check for sample ID line
        if(is_beta==False):
            if line.startswith('^SAMPLE = '):
                current_geo = line.strip().split('= ')[-1]
                sample_geo.append(current_geo)
        
            elif line.startswith('ID_REF	VALUE'):
                actual_betas=[]
                actual_cgs=[]
                is_beta=True
        else:
            if line.startswith('!sample_table_end'):
                sample_cgs.append(actual_cgs)
                sample_betas.append(actual_betas)
                is_beta=False
            else:
                elements=line.strip().split('\t')
                actual_cgs.append(elements[0]) 
                actual_betas.append(elements[1])

# %%
#print(all_lists_equal(sample_cgs)) #True so now we can create dataframe since the order and sites are the same
GSE49149_df = create_dataframe(sample_betas, sample_geo, sample_cgs[0])
GSE49149_df.to_csv('GSE49149_betas.csv') 
GSE49149_df
# Out:
#                   GSM1194354   GSM1194355   GSM1194356   GSM1194357  \
# cg00000165       0.236761977  0.603708038  0.257132812  0.436311675
# cg00000363        0.37734014   0.20712197  0.319522028  0.317945082
# cg00001349       0.602949217  0.765146527  0.645981894  0.692175078
# cg00001364       0.798663511  0.833834854  0.858607305  0.861442447
# cg00001446       0.885168661  0.735939333  0.853466277  0.852774323
# ...                      ...          ...          ...          ...
# ch.22.44116734F  0.068453356  0.076006821   0.10555043  0.061835872
# ch.22.909671F    0.200480248  0.088707353  0.261597669  0.165917225
# ch.22.46830341F  0.039519379  0.035543004  0.043136684  0.026021322
# ch.22.1008279F   0.023339791  0.020927258  0.028596747  0.031319065
# ch.22.47579720R  0.045688284  0.082268315  0.067552603  0.073293611
#
#                   GSM1194358   GSM1194359   GSM1194360   GSM1194361  \
# cg00000165       0.206783456  0.515761791   0.48362313  0.529192407
# ...

# %%
import pandas as pd
#run time 5min

file_path = 'GSE52068_family.soft'

sample_geo = []
sample_cgs=[]
sample_betas=[]
is_beta=False

with open(file_path, 'r') as file:
    for line in file:
        # Check for sample ID line
        if(is_beta==False):
            if line.startswith('^SAMPLE = '):
                current_geo = line.strip().split('= ')[-1]
                sample_geo.append(current_geo)
        
            elif line.startswith('ID_REF	VALUE'):
                actual_betas=[]
                actual_cgs=[]
                is_beta=True
        else:
            if line.startswith('!sample_table_end'):
                sample_cgs.append(actual_cgs)
                sample_betas.append(actual_betas)
                is_beta=False
            else:
                elements=line.strip().split('\t')
                actual_cgs.append(elements[0]) 
                actual_betas.append(elements[1])

# %%
#print(all_lists_equal(sample_cgs)) #so now we can create dataframe since the order and sites are the same
GSE52068_df = create_dataframe(sample_betas, sample_geo, sample_cgs[0])
GSE52068_df.to_csv('GSE52068_betas.csv')
GSE52068_df
# Out:
#              GSM1258183   GSM1258184   GSM1258185   GSM1258186   GSM1258187  \
# cg00000029   0.57483913  0.384654995  0.620099627  0.499900513  0.515012531
# cg00000108  0.896455596     7.77E-07  0.905052475  0.925226704  0.897789694
# cg00000109   0.82788534  0.829778451  0.828555676  0.797083288  0.871862902
# cg00000165  0.165489789   0.44443776  0.281419977  0.269409696  0.346994726
# cg00000236  0.849449782  0.861773164  0.853722089  0.869762305  0.862614165
# ...                 ...          ...          ...          ...          ...
# rs9363764   0.424851541  0.469254995  0.040130644  0.493123462  0.911893861
# rs939290     0.51994712  0.342945383  0.557891232   0.51954754  0.925639217
# rs951295    0.038823264  0.059215004  0.054537817  0.927513834  0.925649727
# rs966367       2.04E-05  0.388147516  0.000432051     1.08E-07  0.212248835
# rs9839873    0.94109439  0.927899248  0.949558329   0.94269335  0.923437296
#
# ...

# %%
import pandas as pd
#run time 5min

file_path = 'GSE59157_family.soft'

sample_geo = []
sample_cgs=[]
sample_betas=[]
is_beta=False

with open(file_path, 'r') as file:
    for line in file:
        # Check for sample ID line
        if(is_beta==False):
            if line.startswith('^SAMPLE = '):
                current_geo = line.strip().split('= ')[-1]
                sample_geo.append(current_geo)
        
            elif line.startswith('ID_REF	VALUE'):
                actual_betas=[]
                actual_cgs=[]
                is_beta=True
        else:
            if line.startswith('!sample_table_end'):
                sample_cgs.append(actual_cgs)
                sample_betas.append(actual_betas)
                is_beta=False
            else:
                elements=line.strip().split('\t')
                actual_cgs.append(elements[0]) 
                actual_betas.append(elements[1])

# %%
#print(all_lists_equal(sample_cgs)) #True so now we can create dataframe since the order and sites are the same
GSE59157_df = create_dataframe(sample_betas, sample_geo, sample_cgs[0])
GSE59157_df.to_csv('GSE59157_betas.csv')
GSE59157_df
# Out:
#                  GSM1429528   GSM1429529   GSM1429530   GSM1429531  \
# cg00000029      0.321882027  0.420860444   0.40094873  0.595341763
# cg00000108      0.912291225   0.87452043  0.872644165    0.8684039
# cg00000109       0.76338886  0.840998038  0.780880675  0.824649752
# cg00000165       0.19384631  0.170858655   0.27235939   0.33135811
# cg00000236      0.724747475  0.736467617  0.658260176  0.660295063
# ...                     ...          ...          ...          ...
# ch.X.97129969R  0.125403837  0.100102548     0.148806  0.088892953
# ch.X.97133160R  0.158403652  0.197376768  0.222063371  0.175069644
# ch.X.97651759F  0.113471846  0.050944086  0.134021582  0.119490247
# ch.X.97737721F  0.125182113  0.140950566  0.311123886  0.155517028
# ch.X.98007042R  0.102387464  0.163256797  0.195700613  0.200587452
#
#                  GSM1429532   GSM1429533   GSM1429534   GSM1429535  \
# cg00000029      0.429466109  0.320516427  0.248992716  0.431891032
# ...

# %%
import pandas as pd
#run time 5min

file_path = 'GSE77955_family.soft'

sample_geo = []
sample_cgs=[]
sample_betas=[]
is_beta=False

with open(file_path, 'r') as file:
    for line in file:
        # Check for sample ID line
        if(is_beta==False):
            if line.startswith('^SAMPLE = '):
                current_geo = line.strip().split('= ')[-1]
                sample_geo.append(current_geo)
        
            elif line.startswith('ID_REF	VALUE'):
                actual_betas=[]
                actual_cgs=[]
                is_beta=True
        else:
            if line.startswith('!sample_table_end'):
                sample_cgs.append(actual_cgs)
                sample_betas.append(actual_betas)
                is_beta=False
            else:
                elements=line.strip().split('\t')
                actual_cgs.append(elements[0]) 
                actual_betas.append(elements[1])

#this is the aggregated data of two measurements so the first 58 is measured with another method so irrelevant for us
#the first 58 should be deleted from every list
sample_geo = sample_geo[58:]          
sample_cgs = sample_cgs[58:]    
sample_betas = sample_betas[58:]

# %%
#print(all_lists_equal(sample_cgs)) #True so now we can create dataframe since the order and sites are the same
GSE77955_df = create_dataframe(sample_betas, sample_geo, sample_cgs[0])
GSE77955_df.to_csv('GSE77955_betas_NOT_NORMALIZED.csv') # this is the unnormalized data, should be converted to beta values from m-values
GSE77955_df
# Out:
#                     GSM2062364         GSM2062365         GSM2062366  \
# cg13869341    2.47828216939372   2.69608537310075   2.33522505413935
# cg14008030    1.23138093337051   1.37200329909941   1.30014308811978
# cg12045430   -2.51276618724849  -1.89587637655761  -2.15853249954174
# cg20826792   -1.57080843037979   -1.4334821585794  -1.37852020213605
# cg00381604   -3.91460158336293  -3.19817274185087  -3.62766116998442
# ...                        ...                ...                ...
# cg17939569  -0.113267456080371  -0.44204269214857  0.828879509519076
# cg13365400  0.0600835423340617  0.982116213604636   1.88133567559163
# cg21106100     2.4146528051057   2.65838713960975   2.22969639856531
# cg08265308    3.15288589921699   3.03213048812108   3.28101705227318
# cg14273923    2.16055403481977   1.83292588322184    2.4241458332014
#
#                      GSM2062367         GSM2062368           GSM2062369  \
# ...

# %%
# count nans before beta value conversion (it would cause error)
# Convert all values to float, replacing errors with NaN
GSE37754_df = GSE37754_df.apply(pd.to_numeric, errors='coerce')
# Count total NaN values
nan_count = GSE37754_df.isna().sum().sum()
print(f"Total NaN values in the DataFrame: {nan_count}")
# Out:
# Total NaN values in the DataFrame: 0

# %%
# count nans before beta value conversion (it would cause error)
# Convert all values to float, replacing errors with NaN
GSE77955_df = GSE77955_df.apply(pd.to_numeric, errors='coerce')
# Count total NaN values
nan_count = GSE77955_df.isna().sum().sum()
print(f"Total NaN values in the DataFrame: {nan_count}")
# Out:
# Total NaN values in the DataFrame: 0

# %%
# Convert M-values to Beta values
def m_to_beta(m_values):
    return 2**m_values / (2**m_values + 1)

# Apply the function to the entire dataframe
GSE37754_df_beta = GSE37754_df.apply(m_to_beta)
GSE77955_df_beta = GSE77955_df.apply(m_to_beta)
#now we can save the beta values to csv files
GSE37754_df_beta.to_csv('GSE37754_betas.csv')
GSE77955_df_beta.to_csv('GSE77955_betas.csv')
